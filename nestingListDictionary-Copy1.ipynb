# %%
print("storing dictionaries in list")
print("------------------------------------------------------------------------------------")
user = []
user1 = {'first': 'jade', 'last':'white', 'id':'abc'}
user.append(user1)
print(user)
user2 = {'first': 'jack', 'last':'chance', 'id':'pqr'}
user.append(user2)
print(user)
print()

print("Showing all info about user")
print("------------------------------------------------------------------------------------")
print()
for i in user:
    for k, v in i.items():
        print(k + ":" + v)
    print()

print("List in a dictionary")
print("------------------------------------------------------------------------------------")
fav_lang ={
    'jen':['python','c++'],
    'jack':['ruby','c','html'],
    'mari':['java', 'php','js'],
    'phill':['kdb','python'],
}
for k, v in fav_lang.items():
    print(k + ":")
    print("-------")
    for l in v:
        print("-" + l)
    print()
print()

#dictionries of dictionries

print("dictionary of dictionary")
print("------------------------------------------------------------------------------------")
user = {'Markw': {'fName':'Mark', 'lName': 'White', 'Language': 'python'},
        'jadec':{'fName':'Jade', 'lName': 'Chance', 'Language': 'Java'},
        'Jasonc':{'fName':'Jason', 'lName': 'Clarke', 'Language': 'C'}}
for k, v in user.items():
    print("User name: " + k)
    full_info = v['fName'] + " "
    full_info += v['lName']
    Language = v['Language']
    
    print("Full name: " + full_info.title())
    print("Language: " + Language.title())
    print()
print()

#using an orderedDict
"""from collections import orderedDict
print("Preserving the order of Keys and Values")

fav_lang = orderedDict()
fav_lang ={
    'jen':['python','c++'],
    'jack':['ruby','c','html'],
    'mari':['java', 'php','js'],
    'phill':['kdb','python'],
}
for k, v in fav_lang:
    print(Name + ":")
    for i in v:
        print("-" + v)"""
        
#generating million dictionaries

print("generating million dictionaries")
print("----------------------------------------------------------------------------")
alien = []

for num in range(1000000):
    new_alien = {}
    new_alien['color'] = 'green'
    new_alien['score'] = '225'
    new_alien['size'] = 'UK-10'
    new_alien['x'] = '2 * num'
    new_alien['y'] = '0'
    alien.append(new_alien)
    
print("Length of alien is: ",len(alien))
# Out:
# storing dictionaries in list
# ------------------------------------------------------------------------------------
# [{'first': 'jade', 'last': 'white', 'id': 'abc'}]
# [{'first': 'jade', 'last': 'white', 'id': 'abc'}, {'first': 'jack', 'last': 'chance', 'id': 'pqr'}]
#
# Showing all info about user
# ------------------------------------------------------------------------------------
#
# first:jade
# last:white
# id:abc
#
# first:jack
# last:chance
# id:pqr
#
# List in a dictionary
# ------------------------------------------------------------------------------------
# jen:
# -------
# -python
# -c++
#
# jack:
# -------
# -ruby
# -c
# -html
#
# mari:
# -------
# -java
# -php
# -js
#
# phill:
# -------
# -kdb
# -python
#
#
# dictionary of dictionary
# ------------------------------------------------------------------------------------
# User name: Markw
# Full name: Mark White
# Language: Python
#
# User name: jadec
# Full name: Jade Chance
# Language: Java
#
# User name: Jasonc
# ...
